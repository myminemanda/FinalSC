# %% [markdown]
# # Proyek Analisis Data

# %% [markdown]
# ## Menyaipkan semua library yang dibuthkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
customers_df = pd.read_csv("/content/drive/MyDrive/Dataset PML/customers.csv")
customers_df.head()
# Out:
#    customer_id             gender  age                    home_address  \
# 0            1             Female   30  8606 Victoria TerraceSuite 560
# 1            2  Prefer not to say   69      8327 Kirlin SummitApt. 461
# 2            3  Prefer not to say   59       269 Gemma SummitSuite 109
# 3            4  Prefer not to say   67       743 Bailey GroveSuite 141
# 4            5  Prefer not to say   30         48 Hyatt ManorSuite 375
#
#    zip_code               city                         state    country
# 0      5464      Johnstonhaven            Northern Territory  Australia
# 1      8223    New Zacharyfort               South Australia  Australia
# 2      5661           Aliburgh  Australian Capital Territory  Australia
# 3      1729  South Justinhaven                    Queensland  Australia
# 4      4032     Griffithsshire                    Queensland  Australia

# %%
orders_df = pd.read_csv("/content/drive/MyDrive/Dataset PML/orders.csv")
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %%
product_df = pd.read_csv("/content/drive/MyDrive/Dataset PML/products.csv")
product_df.head()
# Out:
#    product_id product_type  product_name size colour  price  quantity  \
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#
#                                     description
# 0  A red coloured, XS sized, Oxford Cloth Shirt
# 1   A red coloured, S sized, Oxford Cloth Shirt
# 2   A red coloured, M sized, Oxford Cloth Shirt
# 3   A red coloured, L sized, Oxford Cloth Shirt
# 4  A red coloured, XL sized, Oxford Cloth Shirt

# %%
sales_df = pd.read_csv("/content/drive/MyDrive/Dataset PML/sales.csv")
sales_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0         0         1         218             106         2        212.0
# 1         1         1         481             118         1        118.0
# 2         2         1           2              96         3        288.0
# 3         3         1        1002             106         2        212.0
# 4         4         1         691             113         3        339.0

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Menilai tabel `customers_df`

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customer_id   1007 non-null   int64
#  1   gender        989 non-null    object
#  2   age           1007 non-null   int64
#  3   home_address  1007 non-null   object
#  4   zip_code      1007 non-null   int64
#  5   city          1007 non-null   object
#  6   state         1007 non-null   object
#  7   country       1007 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 63.1+ KB

# %%
customers_df.isna().sum()
# Out:
# customer_id      0
# gender          18
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  6

# %%
customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1007.000000  1007.000000  1007.000000
# mean    501.726912    50.929494  5012.538232
# std     288.673238    30.516299  2885.836112
# min       1.000000    20.000000     2.000000
# 25%     252.500000    34.000000  2403.500000
# 50%     502.000000    50.000000  5087.000000
# 75%     751.500000    65.000000  7493.500000
# max    1000.000000   700.000000  9998.000000

# %% [markdown]
# #### Menilai tabel `orders_df`

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
orders_df.nunique()
# Out:
# order_id         1000
# customer_id       617
# payment           995
# order_date        291
# delivery_date     305
# dtype: int64

# %%
print("Jumlah duplikasi: ",orders_df.duplicated().sum())
orders_df.describe()
# Out:
# Jumlah duplikasi:  0
#           order_id  customer_id       payment
# count  1000.000000  1000.000000   1000.000000
# mean    500.500000   506.640000  33972.936000
# std     288.819436   277.115502  14451.609047
# min       1.000000     1.000000  10043.000000
# 25%     250.750000   275.250000  21329.250000
# 50%     500.500000   515.000000  33697.500000
# 75%     750.250000   737.250000  46249.000000
# max    1000.000000  1000.000000  59910.000000

# %% [markdown]
# #### Menilai tabel `product_df`

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    1266 non-null   int64
#  1   product_type  1266 non-null   object
#  2   product_name  1266 non-null   object
#  3   size          1266 non-null   object
#  4   colour        1266 non-null   object
#  5   price         1266 non-null   int64
#  6   quantity      1266 non-null   int64
#  7   description   1266 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 79.3+ KB

# %%
print("Jumlah duplikasi: ", product_df.duplicated().sum())

product_df.describe()
# Out:
# Jumlah duplikasi:  6
#         product_id        price     quantity
# count  1266.000000  1266.000000  1266.000000
# mean    627.926540   105.812006    60.138231
# std     363.971586     9.715611    11.682791
# min       0.000000    90.000000    40.000000
# 25%     313.250000    95.250000    50.000000
# 50%     626.500000   109.000000    60.000000
# 75%     942.750000   114.000000    70.000000
# max    1259.000000   119.000000    80.000000

# %% [markdown]
# #### Menilai tabel `sales_df`

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     4981 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 234.5 KB

# %%
sales_df.isna().sum()
# Out:
# sales_id           0
# order_id           0
# product_id         0
# price_per_unit     0
# quantity           0
# total_price       19
# dtype: int64

# %%
print("Jumlah duplikasi: ", sales_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
print("Jumlah duplikasi: ", sales_df.duplicated().sum())
sales_df.describe()
# Out:
# Jumlah duplikasi:  0
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  4981.000000
# mean    206.307368
# std      86.352449
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Membersihkan tabel `customers_df`

# %% [markdown]
# ##### Duplicate data

# %%
customers_df.duplicated().sum()
# Out:
# np.int64(6)

# %%
customers_df.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Missing values

# %%
customers_df.isna().sum()
# Out:
# customer_id      0
# gender          18
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %%
customers_df[customers_df.gender.isna()]
# Out:
#      customer_id gender  age                     home_address  zip_code  \
# 38            39    NaN   80  7440 Cameron Estate DrSuite 628      4622
# 167          168    NaN   27         2781 Berge MallSuite 452      1975
# 322          322    NaN   30        593 Becker CircleApt. 333      1640
# 393          393    NaN   34          5158 Levi HillSuite 531      1474
# 442          442    NaN   26           5157 Feil RoadApt. 633      7249
# 722          720    NaN   40         31 Jordan ParadeApt. 400      1380
# 745          743    NaN   57   09 Christopher StreetSuite 967      6226
# 773          771    NaN   74     7367 Wright JunctionApt. 773      8882
# 798          795    NaN   49          487 Summer MewsApt. 874      1712
# 801          798    NaN   56           27 Aiden KnollApt. 875      6531
# 825          822    NaN   59        41 Jenkins KnollSuite 438      2588
# 859          855    NaN   55       603 O'keefe KnollSuite 782      8822
# 863          859    NaN   38            32 Isla GroveApt. 078      7711
# 914          909    NaN   62    976 Murray Station StApt. 036      3227
# 934          929    NaN   68           394 Lily HillSuite 153      2353
# 948          943    NaN   64       3117 Heller PlaceSuite 149       822
# 952          946    NaN   24      8227 Nicholas HillSuite 150       115
# 994          988    NaN   35   1130 Turner Estate DrSuite 925      9386
#
#                       city                         state    country
# 38   North Victoriachester            Northern Territory  Australia
# 167         North Leoburgh             Western Australia  Australia
# 322             Jacobiview             Western Australia  Australia
# 393             Johnsburgh                    Queensland  Australia
# 442             Port Chloe               New South Wales  Australia
# 722             West Henry               South Australia  Australia
# 745         Lake Lukemouth             Western Australia  Australia
# 773               Kuhntown                      Victoria  Australia
# 798            East Hayden  Australian Capital Territory  Australia
# 801               Port Sam  Australian Capital Territory  Australia
# 825        Lake Andrewport               South Australia  Australia
# 859        Port Dylanmouth                      Tasmania  Australia
# 863            Rosechester               New South Wales  Australia
# 914               Langfort                      Tasmania  Australia
# 934             Beahanfurt            Northern Territory  Australia
# 948           North Elijah               South Australia  Australia
# 952           South Jasper                    Queensland  Australia
# 994              New Harry             Western Australia  Australia

# %%
customers_df.gender.value_counts()
# Out:
# gender
# Prefer not to say    725
# Male                 143
# Female               115
# Name: count, dtype: int64

# %%
customers_df.fillna(value="Prefer not to say", inplace=True)

# %%
customers_df.isna().sum()
# Out:
# customer_id     0
# gender          0
# age             0
# home_address    0
# zip_code        0
# city            0
# state           0
# country         0
# dtype: int64

# %% [markdown]
# ##### Inaccurate value

# %%
customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1001.000000  1001.000000  1001.000000
# mean    500.942058    50.953047  5000.693307
# std     289.013599    30.578437  2886.084454
# min       1.000000    20.000000     2.000000
# 25%     251.000000    34.000000  2398.000000
# 50%     501.000000    50.000000  5079.000000
# 75%     751.000000    65.000000  7454.000000
# max    1000.000000   700.000000  9998.000000

# %%
customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id             gender  age                home_address  \
# 967          961  Prefer not to say  700  29 Farrell ParadeSuite 818
#
#      zip_code        city            state    country
# 967      6528  New Joseph  South Australia  Australia

# %%
customers_df.age.replace(customers_df.age.max(), 70, inplace=True)
# Out:
# /tmp/ipython-input-30-4147959128.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers_df.age.replace(customers_df.age.max(), 70, inplace=True)

# %%
customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id             gender  age            home_address  zip_code  \
# 215          216  Prefer not to say  500  038 Haley MewsApt. 810      3991
#
#           city               state    country
# 215  Bayertown  Northern Territory  Australia

# %%
customers_df.age.replace(customers_df.age.max(), 50, inplace=True)
# Out:
# /tmp/ipython-input-32-606824494.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers_df.age.replace(customers_df.age.max(), 50, inplace=True)

# %%
customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1001.000000  1001.000000  1001.000000
# mean    500.942058    49.874126  5000.693307
# std     289.013599    17.644663  2886.084454
# min       1.000000    20.000000     2.000000
# 25%     251.000000    34.000000  2398.000000
# 50%     501.000000    50.000000  5079.000000
# 75%     751.000000    65.000000  7454.000000
# max    1000.000000    80.000000  9998.000000

# %% [markdown]
# #### Membersihkan tabel `orders_df`

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %% [markdown]
# ##### Memperbaiki tipe data

# %%
datetime_columns = ["order_date", "delivery_date"]

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   datetime64[ns]
#  4   delivery_date  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(3)
# memory usage: 39.2 KB

# %%
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811 2021-08-30    2021-09-24
# 1         2          473    50490 2021-02-03    2021-02-13
# 2         3          774    46763 2021-10-08    2021-11-03
# 3         4          433    39782 2021-05-06    2021-05-19
# 4         5          441    14719 2021-03-23    2021-03-24

# %% [markdown]
# #### Membersihkan tabel `product_df`

# %% [markdown]
# ##### Duplicate data

# %%
product_df[product_df.duplicated()]
# Out:
#      product_id product_type product_name size  colour  price  quantity  \
# 112          54        Shirt        Dress   XL   green    119        52
# 232         146        Shirt        Linen    S  orange    116        42
# 365         146        Shirt        Linen    S  orange    116        42
# 435         377        Shirt       Henley    M  indigo     92        70
# 540         483       Jacket       Puffer    L  indigo    110        61
# 587         579       Jacket       Bomber   XL   green     90        79
#
#                                    description
# 112    A green coloured, XL sized, Dress Shirt
# 232    A orange coloured, S sized, Linen Shirt
# 365    A orange coloured, S sized, Linen Shirt
# 435   A indigo coloured, M sized, Henley Shirt
# 540  A indigo coloured, L sized, Puffer Jacket
# 587  A green coloured, XL sized, Bomber Jacket

# %%
product_df.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi: ", product_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Membersihkan tabel `sales_df`

# %% [markdown]
# ##### Missing values

# %%
sales_df.isna().sum()
# Out:
# sales_id           0
# order_id           0
# product_id         0
# price_per_unit     0
# quantity           0
# total_price       19
# dtype: int64

# %%
sales_df[sales_df.total_price.isna()]
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 9            9         2        1196             105         1          NaN
# 121        121        27        1027              90         3          NaN
# 278        278        63         360              94         2          NaN
# 421        421        95        1091             115         1          NaN
# 489        489       108        1193             105         3          NaN
# 539        539       117         405             119         2          NaN
# 636        636       134         653              93         3          NaN
# 687        687       145        1138             102         1          NaN
# 854        854       177          64             104         1          NaN
# 1079      1079       222         908              94         3          NaN
# 1193      1193       248        1121             102         2          NaN
# 1313      1313       272         826             117         1          NaN
# 1548      1548       316         103             118         3          NaN
# 1688      1688       345         428             107         1          NaN
# 1775      1775       359         694             113         2          NaN
# 1902      1902       381        1218             105         3          NaN
# 2025      2025       408         611             112         3          NaN
# 2164      2164       436         583             100         3          NaN
# 2347      2347       476         696             113         2          NaN

# %%
sales_df["total_price"] = sales_df["price_per_unit"] * sales_df["quantity"]

# %%
sales_df.isna().sum()
# Out:
# sales_id          0
# order_id          0
# product_id        0
# price_per_unit    0
# quantity          0
# total_price       0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore `customers_df`

# %%
customers_df.sample(5)
# Out:
#      customer_id             gender  age                 home_address  \
# 209          210  Prefer not to say   79   476 Mueller CrestSuite 674
# 461          461             Female   54  2501 Hackett ManorSuite 051
# 549          549               Male   50      667 Feil RidgeSuite 935
# 585          584  Prefer not to say   76      85 Brown GroveSuite 561
# 278          279  Prefer not to say   48    179 Richards LoopApt. 131
#
#      zip_code               city                         state    country
# 209      5663  West Claudiaburgh               New South Wales  Australia
# 461        60    West Chasemouth  Australian Capital Territory  Australia
# 549      1919       Gleasonburgh            Northern Territory  Australia
# 585      1559       Charlieburgh                    Queensland  Australia
# 278      5536      New Finnmouth            Northern Territory  Australia

# %%
customers_df.describe(include="all")
# Out:
#         customer_id             gender          age  \
# count   1001.000000               1001  1001.000000
# unique          NaN                  3          NaN
# top             NaN  Prefer not to say          NaN
# freq            NaN                743          NaN
# mean     500.942058                NaN    49.874126
# std      289.013599                NaN    17.644663
# min        1.000000                NaN    20.000000
# 25%      251.000000                NaN    34.000000
# 50%      501.000000                NaN    50.000000
# 75%      751.000000                NaN    65.000000
# max     1000.000000                NaN    80.000000
#
#                       home_address     zip_code        city            state  \
# count                         1001  1001.000000        1001             1001
# unique                        1000          NaN         961                8
# top     3117 Heller PlaceSuite 149          NaN  East Aidan  South Australia
# freq                             2          NaN           3              140
# mean                           NaN  5000.693307         NaN              NaN
# std                            NaN  2886.084454         NaN              NaN
# min                            NaN     2.000000         NaN              NaN
# 25%                            NaN  2398.000000         NaN              NaN
# 50%                            NaN  5079.000000         NaN              NaN
# 75%                            NaN  7454.000000         NaN              NaN
# max                            NaN  9998.000000         NaN              NaN
#
#           country
# count        1001
# unique          1
# top     Australia
# freq         1001
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
customers_df.customer_id.is_unique
# Out:
# False

# %%
customers_df.customer_id.duplicated
# Out:
# <bound method Series.duplicated of 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1002     996
# 1003     997
# 1004     998
# 1005     999
# 1006    1000
# Name: customer_id, Length: 1001, dtype: int64>

# %%
customers_df.groupby(by="gender").agg({
    "customer_id": "nunique",
    "age": ["max", "min", "mean", "std", ]
})
# Out:
#                   customer_id age
#                       nunique max min       mean        std
# gender
# Female                    115  79  20  49.147826  16.646607
# Male                      143  80  20  51.230769  18.462635
# Prefer not to say         742  80  20  49.725437  17.644283

# %%
customers_df.groupby(by="city").customer_id.nunique().sort_values(ascending=False)
# Out:
# city
# East Sophia     3
# New Ava         3
# East Aidan      3
# Lake Sienna     2
# Jademouth       2
#                ..
# Justinport      1
# Kaiberg         1
# Kaifort         1
# Kaihaven        1
# Johnsonhaven    1
# Name: customer_id, Length: 961, dtype: int64

# %%
customers_df.groupby(by="state").customer_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 139
# Queensland                      134
# New South Wales                 132
# Northern Territory              125
# Western Australia               124
# Australian Capital Territory    121
# Victoria                        121
# Tasmania                        104
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Explore `orders_df`

# %%
orders_df.sample(5)
# Out:
#      order_id  customer_id  payment order_date delivery_date
# 989       990           87    40306 2021-08-17    2021-09-06
# 348       349          847    36910 2021-04-13    2021-04-29
# 487       488          638    52570 2021-10-01    2021-10-26
# 966       967          306    32010 2021-10-11    2021-11-07
# 212       213          678    37684 2021-09-14    2021-09-27

# %%
delivery_time = orders_df["delivery_date"] - orders_df["order_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %%
orders_df.sample(5)
# Out:
#      order_id  customer_id  payment order_date delivery_date  delivery_time
# 713       714           50    15121 2021-02-07    2021-02-19           12.0
# 45         46          922    25378 2021-06-22    2021-07-04           12.0
# 923       924          786    43116 2021-04-04    2021-04-18           14.0
# 89         90          809    11475 2021-06-13    2021-07-07           24.0
# 18         19          513    56754 2021-08-30    2021-09-10           11.0

# %%
orders_df.describe(include="all")
# Out:
#           order_id  customer_id       payment                  order_date  \
# count  1000.000000  1000.000000   1000.000000                        1000
# mean    500.500000   506.640000  33972.936000  2021-05-27 18:38:52.800000
# min       1.000000     1.000000  10043.000000         2021-01-01 00:00:00
# 25%     250.750000   275.250000  21329.250000         2021-03-13 18:00:00
# 50%     500.500000   515.000000  33697.500000         2021-05-27 12:00:00
# 75%     750.250000   737.250000  46249.000000         2021-08-12 06:00:00
# max    1000.000000  1000.000000  59910.000000         2021-10-24 00:00:00
# std     288.819436   277.115502  14451.609047                         NaN
#
#              delivery_date  delivery_time
# count                 1000    1000.000000
# mean   2021-06-10 20:31:12      14.078000
# min    2021-01-03 00:00:00       1.000000
# 25%    2021-03-28 00:00:00       8.000000
# 50%    2021-06-11 12:00:00      14.000000
# 75%    2021-08-24 06:00:00      21.000000
# max    2021-11-20 00:00:00      27.000000
# std                    NaN       7.707225

# %%
orders_df.delivery_time.hist()
# Out:
# <Axes: >

# %%
customer_id_in_orders_df =  orders_df.customer_id
customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")
customers_df.sample(5)
# Out:
#      customer_id             gender  age                  home_address  \
# 186          187  Prefer not to say   70  30 Williamson SummitApt. 594
# 233          234  Prefer not to say   37       861 Thomas LoopApt. 385
# 514          514  Prefer not to say   45  3678 Flatley MeadowSuite 659
# 209          210  Prefer not to say   79    476 Mueller CrestSuite 674
# 221          222               Male   40         45 Ethan LoopApt. 390
#
#      zip_code               city            state    country  status
# 186      1007     West Isabelton       Queensland  Australia  Active
# 233      7368           West Zoe         Victoria  Australia  Active
# 514      2633      North Charles         Tasmania  Australia  Active
# 209      5663  West Claudiaburgh  New South Wales  Australia  Active
# 221      2967         Casperland         Tasmania  Australia  Active

# %%
customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active        1000
# Non Active       1
# Name: customer_id, dtype: int64

# %%
customers_df[customers_df.status == "Non Active"]
# Out:
#       customer_id gender  age                home_address  zip_code  \
# 1006         1000   Male   71  1671 Lauren KnollSuite 945      9012
#
#                     city     state    country      status
# 1006  Lake Audreyborough  Tasmania  Australia  Non Active

# %% [markdown]
# ### Explore `orders_df` & `customers_df`

# %% [markdown]
# #### Menggabungkan data `customers_df` dan `orders_df`

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  delivery_time  \
# 0         1           64    30811 2021-08-30    2021-09-24           25.0
# 1         2          473    50490 2021-02-03    2021-02-13           10.0
# 2         3          774    46763 2021-10-08    2021-11-03           26.0
# 3         4          433    39782 2021-05-06    2021-05-19           13.0
# 4         5          441    14719 2021-03-23    2021-03-24            1.0
#
#               gender  age                   home_address  zip_code  \
# 0  Prefer not to say   75      4927 Alice MeadowApt. 960      7787
# 1               Male   61  531 Schmitt BoulevardApt. 010      1744
# 2  Prefer not to say   34       2096 Wilson MewsApt. 714      8590
# 3  Prefer not to say   46        5777 Mayer PassApt. 881      9728
# 4  Prefer not to say   53   33 Richards JunctionApt. 478      7650
#
#                  city              state    country  status
# 0      Sanfordborough    South Australia  Australia  Active
# 1             Annaton    South Australia  Australia  Active
# 2  West Jonathanshire           Tasmania  Australia  Active
# 3    West Michaelport           Tasmania  Australia  Active
# 4     South Rileyview  Western Australia  Australia  Active

# %%
orders_customers_df.groupby(by="city").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# city
# Jordanside          6
# New Ava             6
# Port Hannahburgh    5
# Lake Rose           5
# O'keefeton          5
# East Max            5
# Rubyfort            5
# West Kai            5
# Sarahstad           4
# Russelstad          4
# Name: order_id, dtype: int64

# %%
orders_customers_df.groupby(by="state").order_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 148
# Queensland                      139
# Western Australia               130
# New South Wales                 129
# Victoria                        118
# Australian Capital Territory    118
# Tasmania                        112
# Northern Territory              106
# Name: order_id, dtype: int64

# %%
orders_customers_df.groupby(by="gender").order_id.nunique().sort_values(ascending=False)
# Out:
# gender
# Prefer not to say    725
# Female               139
# Male                 136
# Name: order_id, dtype: int64

# %%
orders_customers_df["age_group"] = orders_customers_df.age.apply(lambda x: "Youth" if x <= 24 else ("Seniors" if x > 64 else "Adults"))

# %%
orders_customers_df.groupby(by="age_group").order_id.nunique().sort_values(ascending=False)
# Out:
# age_group
# Adults     681
# Seniors    226
# Youth       93
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explore `product_df`

# %%
product_df.sample(10)
# Out:
#      product_id product_type     product_name size  colour  price  quantity  \
# 888         882     Trousers            Cords    M  orange    113        53
# 129         128        Shirt            Denim    L    blue    115        45
# 531         527       Jacket          Leather    M     red    113        54
# 572         567       Jacket           Bomber    M  orange     90        69
# 134         133        Shirt            Denim    L  indigo    115        58
# 765         759       Jacket          Peacoat   XL    blue    102        77
# 415         412        Shirt  Casual Slim Fit    M  indigo    113        65
# 858         852     Trousers           Chinos    M  yellow    100        58
# 26           26        Shirt     Oxford Cloth    S  indigo    114        59
# 960         954     Trousers         Slim-Fit   XL  orange    119        78
#
#                                            description
# 888         A orange coloured, M sized, Cords Trousers
# 129              A blue coloured, L sized, Denim Shirt
# 531            A red coloured, M sized, Leather Jacket
# 572          A orange coloured, M sized, Bomber Jacket
# 134            A indigo coloured, L sized, Denim Shirt
# 765          A blue coloured, XL sized, Peacoat Jacket
# 415  A indigo coloured, M sized, Casual Slim Fit Shirt
# 858        A yellow coloured, M sized, Chinos Trousers
# 26      A indigo coloured, S sized, Oxford Cloth Shirt
# 960     A orange coloured, XL sized, Slim-Fit Trousers

# %%
product_df.describe(include="all")
# Out:
#          product_id product_type product_name  size colour        price  \
# count   1260.000000         1260         1260  1260   1260  1260.000000
# unique          NaN            3           35     8      7          NaN
# top             NaN        Shirt        Denim    XS    red          NaN
# freq            NaN          420           70   252    180          NaN
# mean     629.500000          NaN          NaN   NaN    NaN   105.805556
# std      363.874979          NaN          NaN   NaN    NaN     9.704423
# min        0.000000          NaN          NaN   NaN    NaN    90.000000
# 25%      314.750000          NaN          NaN   NaN    NaN    95.750000
# 50%      629.500000          NaN          NaN   NaN    NaN   108.500000
# 75%      944.250000          NaN          NaN   NaN    NaN   114.000000
# max     1259.000000          NaN          NaN   NaN    NaN   119.000000
#
#            quantity                                        description
# count   1260.000000                                               1260
# unique          NaN                                               1260
# top             NaN  A violet coloured, XL sized, Tracksuit Bottoms...
# freq            NaN                                                  1
# mean      60.150000                                                NaN
# std       11.670573                                                NaN
# min       40.000000                                                NaN
# 25%       50.000000                                                NaN
# 50%       60.000000                                                NaN
# 75%       70.000000                                                NaN
# max       80.000000                                                NaN

# %%
product_df.sort_values(by="price", ascending=False)
# Out:
#       product_id product_type product_name size  colour  price  quantity  \
# 671          665       Jacket        Parka   XS     red    119        65
# 672          666       Jacket        Parka    S     red    119        66
# 673          667       Jacket        Parka    M     red    119        56
# 674          668       Jacket        Parka    L     red    119        73
# 675          669       Jacket        Parka   XL     red    119        64
# ...          ...          ...          ...  ...     ...    ...       ...
# 1222        1216     Trousers      Pleated    S  indigo     90        41
# 1229        1223     Trousers      Pleated    L  violet     90        48
# 1228        1222     Trousers      Pleated    M  violet     90        45
# 1227        1221     Trousers      Pleated    S  violet     90        50
# 1226        1220     Trousers      Pleated   XS  violet     90        58
#
#                                         description
# 671          A red coloured, XS sized, Parka Jacket
# 672           A red coloured, S sized, Parka Jacket
# 673           A red coloured, M sized, Parka Jacket
# 674           A red coloured, L sized, Parka Jacket
# 675          A red coloured, XL sized, Parka Jacket
# ...                                             ...
# 1222   A indigo coloured, S sized, Pleated Trousers
# 1229   A violet coloured, L sized, Pleated Trousers
# 1228   A violet coloured, M sized, Pleated Trousers
# 1227   A violet coloured, S sized, Pleated Trousers
# 1226  A violet coloured, XS sized, Pleated Trousers
#
# [1260 rows x 8 columns]

# %%
product_df.groupby(by="product_type").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price":  ["min", "max"]
})
# Out:
#              product_id quantity price
#                 nunique      sum   min  max
# product_type
# Jacket              420    25387    90  119
# Shirt               420    25263    92  119
# Trousers            420    25139    90  119

# %%
product_df.groupby(by="product_name").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price": ["min", "max"]
})
# Out:
#                   product_id quantity price
#                      nunique      sum   min  max
# product_name
# Bomber                    35     2083    90   90
# Camp Collared             35     2071   112  112
# Cardigan                  35     2032   118  118
# Cargo Pants               35     2146   106  106
# Casual Slim Fit           35     2086   113  113
# Chambray                  35     2020   105  105
# Chinos                    35     2101   100  100
# Coach                     35     2158   115  115
# Cords                     35     2260   113  113
# Cropped                   35     2085    99   99
# Cuban Collar              35     2017    93   93
# Denim                     70     4204    92  115
# Drawstring                35     2042   104  104
# Dress                     35     2125   119  119
# Flannel                   35     2135    96   96
# Henley                    35     2051    92   92
# High-Waisted              35     2198    98   98
# Joggers                   35     2107    94   94
# Leather                   35     2276   113  113
# Linen                     35     2138   116  116
# Mandarin Collar           35     2203   108  108
# Oxford Cloth              35     2071   114  114
# Parka                     35     2201   119  119
# Peacoat                   35     2067   102  102
# Pleated                   35     2030    90   90
# Polo                      35     2196   117  117
# Puffer                    35     1946   110  110
# Pullover                  35     2184   114  114
# Relaxed Leg               35     2002    95   95
# Shearling                 35     2169    95   95
# Slim-Fit                  35     2155   119  119
# Tracksuit Bottoms         35     2038    91   91
# Trench Coat               35     2132   112  112
# Windbreaker               35     2085   109  109
# Wool                      35     1975   111  111

# %% [markdown]
# ### Explore `sales_df`

# %%
sales_df.sample(5)
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 884        884       182         705             119         2          238
# 4407      4407       881        1059              93         3          279
# 4548      4548       907         121              92         1           92
# 4816      4816       966         756             109         3          327
# 1828      1828       370         354              94         1           94

# %%
sales_df.describe(include="all")
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  5000.000000
# mean    206.360000
# std      86.357457
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %%
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  delivery_time
# 0         1           64    30811 2021-08-30    2021-09-24           25.0
# 1         2          473    50490 2021-02-03    2021-02-13           10.0
# 2         3          774    46763 2021-10-08    2021-11-03           26.0
# 3         4          433    39782 2021-05-06    2021-05-19           13.0
# 4         5          441    14719 2021-03-23    2021-03-24            1.0

# %%
sales_df.groupby(by="order_id").total_price.sum()
# Out:
# order_id
# 1      1487
# 2      1130
# 3       508
# 4       976
# 5      2043
#        ...
# 995    1127
# 996    1459
# 997     204
# 998    1352
# 999     440
# Name: total_price, Length: 993, dtype: int64

# %% [markdown]
# ### Explore `sales_df` & `product_df`

# %% [markdown]
# #### Menggabungkan data `sales_df` dan `product_df`

# %%
sales_product_df = pd.merge(
    left=sales_df,
    right=product_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sales_product_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  price  quantity_y  \
# 0        Shirt      Chambray    L  orange    105          44
# 1       Jacket        Puffer    S  indigo    110          62
# 2        Shirt  Oxford Cloth    M     red    114          54
# 3     Trousers          Wool    M    blue    111          52
# 4       Jacket         Parka    S  indigo    119          53
#
#                                    description
# 0   A orange coloured, L sized, Chambray Shirt
# 1    A indigo coloured, S sized, Puffer Jacket
# 2  A red coloured, M sized, Oxford Cloth Shirt
# 3      A blue coloured, M sized, Wool Trousers
# 4     A indigo coloured, S sized, Parka Jacket

# %% [markdown]
# Jika diperhatikan terdapat perbedaan antara nilai **price_per_unit** dan **price**. Hal ini bisa terjadi karena adanya potongan harga, biaya operasional, atau biaya lainnya.

# %%
sales_product_df.groupby(by="product_type").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#               sales_id  quantity_x  total_price
# product_type
# Jacket            1676        3343       357026
# Shirt             1641        3259       333600
# Trousers          1683        3360       341174

# %%
sales_product_df.groupby(by="product_name").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
}).sort_values(by="total_price", ascending=False)
# Out:
#                    sales_id  quantity_x  total_price
# product_name
# Denim                   273         527        52399
# Casual Slim Fit         154         306        36414
# Trench Coat             146         299        35581
# Shearling               150         302        35334
# Puffer                  140         298        35164
# Flannel                 141         281        33158
# Cropped                 135         284        32660
# Pleated                 147         308        32340
# Joggers                 164         334        31062
# Chambray                141         290        30740
# Parka                   134         269        30397
# Bomber                  150         297        29700
# Chinos                  135         260        29380
# Windbreaker             143         287        29274
# Cardigan                134         260        29120
# Peacoat                 132         266        28994
# Tracksuit Bottoms       130         257        28784
# Slim-Fit                154         288        27936
# Oxford Cloth            146         289        27744
# Drawstring              147         288        27648
# High-Waisted            140         278        27522
# Camp Collared           139         279        27342
# Cargo Pants             134         267        27234
# Relaxed Leg             146         301        27090
# Cuban Collar            122         254        26670
# Henley                  146         281        26414
# Wool                    125         249        26394
# Leather                 136         263        25774
# Mandarin Collar         124         236        25724
# Dress                   127         243        25272
# Pullover                143         276        25116
# Polo                    131         264        25080
# Coach                   134         265        24645
# Linen                   131         270        24570
# Cords                   126         246        23124

# %% [markdown]
# ### Explore all data

# %% [markdown]
# #### Menghubungkan semua data

# %%
all_df = pd.merge(
    left=sales_product_df,
    right=orders_customers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  ...  delivery_time  \
# 0        Shirt      Chambray    L  orange  ...           25.0
# 1       Jacket        Puffer    S  indigo  ...           25.0
# 2        Shirt  Oxford Cloth    M     red  ...           25.0
# 3     Trousers          Wool    M    blue  ...           25.0
# 4       Jacket         Parka    S  indigo  ...           25.0
#
#               gender age               home_address  zip_code            city  \
# 0  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 1  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 2  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 3  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 4  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
#
#              state    country  status  age_group
# 0  South Australia  Australia  Active    Seniors
# 1  South Australia  Australia  Active    Seniors
# 2  South Australia  Australia  Active    Seniors
# 3  South Australia  Australia  Active    Seniors
# 4  South Australia  Australia  Active    Seniors
#
# [5 rows x 27 columns]

# %%
all_df.groupby(by=["city", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                           quantity_x  total_price
# city        product_type
# Abbeyshire  Jacket                 7          683
#             Shirt                  7          739
#             Trousers              12         1209
# Abbottburgh Jacket                 3          279
#             Shirt                  9          937
# ...                              ...          ...
# Zacharybury Trousers              17         1829
# Zacshire    Jacket                 2          224
#             Shirt                  2          184
# Zacville    Jacket                 6          645
#             Shirt                  4          394
#
# [1602 rows x 2 columns]

# %%
all_df.groupby(by=["state", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                            quantity_x  total_price
# state                        product_type
# Australian Capital Territory Jacket               406        43204
#                              Shirt                396        40448
#                              Trousers             454        46790
# New South Wales              Jacket               451        47998
#                              Shirt                431        43980
#                              Trousers             392        39766
# Northern Territory           Jacket               365        38991
#                              Shirt                336        33865
#                              Trousers             384        38998
# Queensland                   Jacket               499        53511
#                              Shirt                417        42506
#                              Trousers             453        46045
# South Australia              Jacket               461        49090
#                              Shirt                509        52685
#                              Trousers             455        46041
# Tasmania                     Jacket               412        44370
#                              Shirt                387        39668
#                              Trousers             379        38057
# Victoria                     Jacket               359        38203
#                              Shirt                390        40206
#                              Trousers             414        41948
# Western Australia            Jacket               390        41659
#                              Shirt                393        40242
#                              Trousers             429        43529

# %%
all_df.groupby(by=["gender", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                 quantity_x  total_price
# gender            product_type
# Female            Jacket               481        50963
#                   Shirt                445        45146
#                   Trousers             481        49295
# Male              Jacket               480        50978
#                   Shirt                410        41939
#                   Trousers             453        46071
# Prefer not to say Jacket              2382       255085
#                   Shirt               2404       246515
#                   Trousers            2426       245808

# %%
all_df.groupby(by=["age_group", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                         quantity_x  total_price
# age_group product_type
# Adults    Jacket              2292       245055
#           Shirt               2225       227781
#           Trousers            2272       231271
# Seniors   Jacket               777        82959
#           Shirt                733        74977
#           Trousers             766        77471
# Youth     Jacket               274        29012
#           Shirt                301        30842
#           Trousers             322        32432

# %%
all_df.groupby(by="state").agg({
    "order_id": "nunique",
    "total_price": "sum"
}).sort_values(by="total_price", ascending=False)
# Out:
#                               order_id  total_price
# state
# South Australia                    144       147816
# Queensland                         139       142062
# New South Wales                    129       131744
# Australian Capital Territory       118       130442
# Western Australia                  130       125430
# Tasmania                           112       122095
# Victoria                           115       120357
# Northern Territory                 106       111854

# %%
all_df.to_csv("all_data.csv", index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Bagaimana performa penjualan dan revenue perusahaan dalam beberapa bulan terakhir?

# %%
all_df.sample(5)
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 2625      2625       526         251              95           3          285
# 4017      4017       800        1203             105           3          315
# 4171      4171       830         238             106           3          318
# 4562      4562       909         613             112           1          112
# 2767      2767       554        1127             102           3          306
#
#      product_type product_name size  colour  ...  delivery_time  \
# 2625        Shirt         Polo    S  orange  ...            6.0
# 4017     Trousers      Pleated    L  yellow  ...            2.0
# 4171        Shirt     Chambray    L  indigo  ...            1.0
# 4562       Jacket     Cardigan    L   green  ...           22.0
# 2767     Trousers  Cargo Pants    M  orange  ...           19.0
#
#                  gender age                  home_address  zip_code  \
# 2625  Prefer not to say  45     91 Angelina RidgeApt. 435      9871
# 4017  Prefer not to say  34      58 Heaney SquareApt. 870      1342
# 4171  Prefer not to say  20     408 Logan View RdApt. 841      6905
# 4562             Female  38  115 Wilkinson CrestSuite 858      4700
# 2767  Prefer not to say  70   735 Goldner AvenueSuite 768      8388
#
#                   city              state    country  status  age_group
# 2625  Lake Phoenixside    South Australia  Australia  Active     Adults
# 4017       Feeneymouth         Queensland  Australia  Active     Adults
# 4171   New Alexchester    New South Wales  Australia  Active      Youth
# 4562      Williammouth           Victoria  Australia  Active     Adults
# 2767        Port Kiara  Western Australia  Australia  Active    Seniors
#
# [5 rows x 27 columns]

# %%
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  delivery_time
# 0         1           64    30811 2021-08-30    2021-09-24           25.0
# 1         2          473    50490 2021-02-03    2021-02-13           10.0
# 2         3          774    46763 2021-10-08    2021-11-03           26.0
# 3         4          433    39782 2021-05-06    2021-05-19           13.0
# 4         5          441    14719 2021-03-23    2021-03-24            1.0

# %%
monthly_orders_df = all_df.resample(rule='M', on='order_date').agg({
    "order_id": "nunique",
    "total_price": "sum"
})
monthly_orders_df.index = monthly_orders_df.index.strftime('%B') #mengubah format order date menjadi Tahun-Bulan
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
    "total_price": "revenue"
}, inplace=True)
monthly_orders_df.head()
# Out:
# /tmp/ipython-input-87-3584057361.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_orders_df = all_df.resample(rule='M', on='order_date').agg({
#   order_date  order_count  revenue
# 0    January          109   119333
# 1   February           93    95080
# 2      March          117   131364
# 3      April           99    97530
# 4        May           84    85597

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    monthly_orders_df["order_date"],
    monthly_orders_df["order_count"],
    marker='o',
    linewidth=2,
    color="#72BCD4"
)
plt.title("Number of Orders per Month (2021)", loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    monthly_orders_df["order_date"],
    monthly_orders_df["revenue"],
    marker='o',
    linewidth=2,
    color="#72BCD4"
)
plt.title("Total Revenue per Month in 2021 (AUD)", loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### Produk apa yang paling banyak dan paling sedikit terjual?

# %%
sum_order_items_df = all_df.groupby("product_name").quantity_x.sum().sort_values(ascending=False).reset_index()
sum_order_items_df.head(10)
# Out:
#       product_name  quantity_x
# 0            Denim         527
# 1          Joggers         334
# 2          Pleated         308
# 3  Casual Slim Fit         306
# 4        Shearling         302
# 5      Relaxed Leg         301
# 6      Trench Coat         299
# 7           Puffer         298
# 8           Bomber         297
# 9         Chambray         290

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=18)
ax[0].tick_params(axis ='y', labelsize=15)

sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.sort_values(by="quantity_x", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)

plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()
# Out:
# /tmp/ipython-input-92-4275052777.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
# /tmp/ipython-input-92-4275052777.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.sort_values(by="quantity_x", ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# ### Bagaimana demografi pelanggan yang kita miliki?

# %% [markdown]
# #### Berdasarkan gender

# %%
bygeder_df = all_df.groupby(by="gender").customer_id.nunique().reset_index()
bygeder_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
bygeder_df
# Out:
#               gender  customer_count
# 0             Female              73
# 1               Male              82
# 2  Prefer not to say             461

# %%
plt.figure(figsize=(10, 5))

sns.barplot(
    y="customer_count",
    x="gender",
    data=bygeder_df.sort_values(by="customer_count", ascending=False),
    palette=colors
)
plt.title("Number of Customer by Gender", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()
# Out:
# /tmp/ipython-input-94-4096043742.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipython-input-94-4096043742.py:3: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.barplot(

# %% [markdown]
# #### Berdasarkan kelompok usia

# %%
byage_df = all_df.groupby(by="age_group").customer_id.nunique().reset_index()
byage_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
byage_df
# Out:
#   age_group  customer_count
# 0    Adults             416
# 1   Seniors             145
# 2     Youth              55

# %%
byage_df['age_group'] = pd.Categorical(byage_df['age_group'], ["Youth", "Adults", "Seniors"])

# %%
plt.figure(figsize=(10, 5))
colors_ = ["#D3D3D3", "#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    y="customer_count",
    x="age_group",
    data=byage_df.sort_values(by="age_group", ascending=False),
    palette=colors_
)
plt.title("Number of Customer by Age", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()
# Out:
# /tmp/ipython-input-97-2389070131.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /tmp/ipython-input-97-2389070131.py:4: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.barplot(

# %% [markdown]
# #### Berdasarkan Negara Bagian

# %%
bystate_df = all_df.groupby(by="state").customer_id.nunique().reset_index()
bystate_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
bystate_df
# Out:
#                           state  customer_count
# 0  Australian Capital Territory              73
# 1               New South Wales              77
# 2            Northern Territory              75
# 3                    Queensland              79
# 4               South Australia              90
# 5                      Tasmania              67
# 6                      Victoria              75
# 7             Western Australia              80

# %%
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="customer_count",
    y="state",
    data=bystate_df.sort_values(by="customer_count", ascending=False),
    palette=colors_
)
plt.title("Number of Customer by States", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# /tmp/ipython-input-99-2280010845.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# plt.figure(figsize=(10, 5))
# sns.barplot(
#     x="order_count",
#     y="state",
#     data=bystate_df.sort_values(by="order_count", ascending=False),
#     palette=colors_
# )
# plt.title("Number of Orders by States", loc="center", fontsize=15)
# plt.ylabel(None)
# plt.xlabel(None)
# plt.tick_params(axis='y', labelsize=12)
# plt.show()

# %% [markdown]
# ### RFM Analysis

# %%
rfm_df = all_df.groupby(by="customer_id", as_index=False).agg({
    "order_date": "max", #mengambil tanggal order terakhir
    "order_id": "nunique",
    "total_price": "sum"
})
rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]
rfm_df.head()
# Out:
#    customer_id max_order_timestamp  frequency  monetary
# 0            1          2021-04-04          3      1641
# 1            7          2021-05-21          1      1017
# 2           10          2021-03-09          1       270
# 3           11          2021-05-28          1       382
# 4           12          2021-06-19          1      1551

# %%
# menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = orders_df["order_date"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)
rfm_df.head()
# Out:
#    customer_id max_order_timestamp  frequency  monetary  recency
# 0            1          2021-04-04          3      1641      203
# 1            7          2021-05-21          1      1017      156
# 2           10          2021-03-09          1       270      229
# 3           11          2021-05-28          1       382      149
# 4           12          2021-06-19          1      1551      127

# %%
rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#    customer_id  frequency  monetary  recency
# 0            1          3      1641      203
# 1            7          1      1017      156
# 2           10          1       270      229
# 3           11          1       382      149
# 4           12          1      1551      127

# %%
rfm_df.describe()
# Out:
#        customer_id   frequency     monetary     recency
# count    616.00000  616.000000   616.000000  616.000000
# mean     501.75974    1.612013  1675.000000  122.469156
# std      286.16075    0.853754  1069.724092   84.326017
# min        1.00000    1.000000   100.000000    0.000000
# 25%      259.50000    1.000000   878.250000   50.750000
# 50%      496.50000    1.000000  1439.000000  110.500000
# 75%      751.00000    2.000000  2165.000000  191.000000
# max     1000.00000    6.000000  7632.000000  296.000000

# %%
rfm_df.sort_values(by="recency", ascending=True).head(5)
# Out:
#      customer_id  frequency  monetary  recency
# 426          690          3      3693        0
# 425          687          1      1122        0
# 241          401          4      3093        0
# 98           163          3      3494        1
# 250          415          2      2269        1

# %%
rfm_df.sort_values(by="frequency", ascending=False).head(5)
# Out:
#      customer_id  frequency  monetary  recency
# 350          571          6      6640       66
# 212          348          5      5119       24
# 409          664          5      6341       20
# 166          282          5      7632       63
# 346          566          5      5435        5

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)

sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)

sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)

plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()
# Out:
# /tmp/ipython-input-107-4286489001.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
# /tmp/ipython-input-107-4286489001.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
# /tmp/ipython-input-107-4286489001.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])

# %% [markdown]
# #### Mengurutkan customer berdasarkan recency, frequency, & monetary score

# %%
rfm_df['r_rank'] = rfm_df['recency'].rank(ascending=False)
rfm_df['f_rank'] = rfm_df['frequency'].rank(ascending=True)
rfm_df['m_rank'] = rfm_df['monetary'].rank(ascending=True)

rfm_df.head()
# Out:
#    customer_id  frequency  monetary  recency  r_rank  f_rank  m_rank
# 0            1          3      1641      203   133.0   560.0   351.0
# 1            7          1      1017      156   215.5   179.5   195.5
# 2           10          1       270      229    83.0   179.5    11.0
# 3           11          1       382      149   233.0   179.5    21.0
# 4           12          1      1551      127   267.5   179.5   330.0

# %%
# normalizing the rank of the customers
rfm_df['r_rank_norm'] = (rfm_df['r_rank']/rfm_df['r_rank'].max())*100
rfm_df['f_rank_norm'] = (rfm_df['f_rank']/rfm_df['f_rank'].max())*100
rfm_df['m_rank_norm'] = (rfm_df['m_rank']/rfm_df['m_rank'].max())*100

rfm_df.drop(columns=['r_rank', 'f_rank', 'm_rank'], inplace=True)

rfm_df.head()
# Out:
#    customer_id  frequency  monetary  recency  r_rank_norm  f_rank_norm  \
# 0            1          3      1641      203    21.626016    90.909091
# 1            7          1      1017      156    35.040650    29.139610
# 2           10          1       270      229    13.495935    29.139610
# 3           11          1       382      149    37.886179    29.139610
# 4           12          1      1551      127    43.495935    29.139610
#
#    m_rank_norm
# 0    56.980519
# 1    31.737013
# 2     1.785714
# 3     3.409091
# 4    53.571429

# %%
rfm_df['RFM_score'] = 0.15*rfm_df['r_rank_norm']+0.28 * \
    rfm_df['f_rank_norm']+0.57*rfm_df['m_rank_norm']
rfm_df['RFM_score'] *= 0.05
rfm_df = rfm_df.round(2)
rfm_df[['customer_id', 'RFM_score']].head(7)
# Out:
#    customer_id  RFM_score
# 0            1       3.06
# 1            7       1.58
# 2           10       0.56
# 3           11       0.79
# 4           12       2.26
# 5           13       1.14
# 6           15       3.84

# %% [markdown]
# #### Segmentasi customer berdasarkan RFM_score

# %%
rfm_df["customer_segment"] = np.where(
    rfm_df['RFM_score'] > 4.5, "Top customers", (np.where(
        rfm_df['RFM_score'] > 4, "High value customer",(np.where(
            rfm_df['RFM_score'] > 3, "Medium value customer", np.where(
                rfm_df['RFM_score'] > 1.6, 'Low value customers', 'lost customers'))))))

rfm_df[['customer_id', 'RFM_score', 'customer_segment']].head(20)
# Out:
#     customer_id  RFM_score       customer_segment
# 0             1       3.06  Medium value customer
# 1             7       1.58         lost customers
# 2            10       0.56         lost customers
# 3            11       0.79         lost customers
# 4            12       2.26    Low value customers
# 5            13       1.14         lost customers
# 6            15       3.84  Medium value customer
# 7            16       2.33    Low value customers
# 8            18       3.30  Medium value customer
# 9            19       1.68    Low value customers
# 10           20       3.24  Medium value customer
# 11           21       3.88  Medium value customer
# 12           22       2.86    Low value customers
# 13           23       1.91    Low value customers
# 14           25       1.80    Low value customers
# 15           26       2.18    Low value customers
# 16           27       1.89    Low value customers
# 17           28       4.17    High value customer
# 18           34       1.69    Low value customers
# 19           35       3.26  Medium value customer

# %%
customer_segment_df = rfm_df.groupby(by="customer_segment", as_index=False).customer_id.nunique()
customer_segment_df
# Out:
#         customer_segment  customer_id
# 0    High value customer           50
# 1    Low value customers          204
# 2  Medium value customer          137
# 3          Top customers           35
# 4         lost customers          190

# %%
customer_segment_df['customer_segment'] = pd.Categorical(customer_segment_df['customer_segment'], [
    "lost customers", "Low value customers", "Medium value customer",
    "High value customer", "Top customers"
])

# %%
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    x="customer_id",
    y="customer_segment",
    data=customer_segment_df.sort_values(by="customer_segment", ascending=False),
    palette=colors_
)
plt.title("Number of Customer for Each Segment", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# /tmp/ipython-input-114-2998268266.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
